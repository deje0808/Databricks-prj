# %%
# Environment selector: dev, test, prod
env = "dev"

bronze_schema = f"{env}_catalog.bronze"
silver_schema = f"{env}_catalog.silver"
gold_schema   = f"{env}_catalog.gold"

print(f"Running in {env} environment")
